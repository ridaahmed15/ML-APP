# %% [markdown]
# ## Machine Learning with python: Linear Regression with one variable

# %% [markdown]
# ##### Sample problem of predicting home price in monroe, newjery (USA)

# %%
import pandas as pd

# %%
df=pd.read_csv("home_price.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# # Problem Statement:
# ###### Given above data build a machine learning model that can predict home prices based on square feet area

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('area') #x independent variable hai
plt.ylabel('price')#y dependent variable hai
plt.scatter(df.area,df.price,color="red")

# %%
type(df.price) #single dimension
# Out:
# pandas.Series

# %%
type(df[["area"]])  #single dimensional #price series me honi chhye or area 2 dimensional
# Out:
# pandas.DataFrame

# %%
#y=mx+c #machine learning ka model is formula p chlta
#y=(prediction value or target or dependent variable) for ex: price
#m=slope
#x=(independent variable) for ex:area
#c=y-intercept

# %%
#y=m1x1+c1,m2x2+c2,m3x3+c3

# %%
df#y(price)=mx(area)+c
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
price = df.price

# %% [raw]
# price

# %%
x=df.drop('price',axis='columns')  #price ko drop kra tw hmre ps sirf area bacha

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
df[["area"]]
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
# !pip install sci-kit learn
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### sci-kit learn?

# %% [markdown]
# ##science kit for the purpose of machine learning algorithms
# ## -Feature Engineering
# ## -Data Preprocessing
# ## -Model Selections
# ## -Used for the purpose of model development in terms of supervised,unsupervised learnings

# %%
from sklearn import linear_model

# %% [raw]
# ## linear_model= linear Rege=ression/logical regression etc #aesy algorithms jo line me graph  krdy

# %%
 ##www.mathisfun.com/algebra/linear-equations.html

# %%
#CREATING LINEAE MODEL OBJECT

reg = linear_model.LinearRegression()

# %%
reg.fit(x,price)  #training k lie data daleingy tky furtheron predict krsky
# Out:
# LinearRegression()

# %%
reg.predict([[10000]])
# Out:
# C:\Users\sahil\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1538493.15068493])

# %%
import pickle   #compile krdega /binary file me krdeta hai-only for machine understanding

# %%
pickle.dump(reg,open("area.pkl","wb")) #wb=write binary  dump=cover,hide
